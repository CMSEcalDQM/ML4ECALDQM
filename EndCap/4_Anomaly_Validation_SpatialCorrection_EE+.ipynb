# %%
import numpy as np
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib.ticker import MaxNLocator
from skimage.measure import block_reduce # pip install scikit-image
import mpl_scatter_density
import glob, os, time
from torch.utils.data import Dataset, ConcatDataset, DataLoader, sampler
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
from sklearn.metrics import roc_curve, auc
from utils import *
import warnings
import copy
warnings.filterwarnings('ignore')
# %matplotlib inline
np.random.seed(0)

# %%
figOutDir = './PLOTS/4_Anomaly_Validation_SpatialCorrection_EE+/'
os.system('mkdir -p {}'.format(figOutDir))
# Out:
# 0

# %% [markdown]
# ### Get Data

# %%
# Import data

files = glob.glob('../DATA/500ev_EE_ECALDQM_*.parquet')
print('Total number of parquet files: {}'.format(len(files)))
#f = [pq.ParquetFile(i) for i in files]

print('\nError reading the file below: ')
f = []
for i in range(len(files)):
    try:
        f.append(pq.ParquetFile(files[i]))
    except:
        print(files[i])
        files[i] = None
files.remove(None)

nEntries = [i.num_row_groups for i in f]
# Out:
# Total number of parquet files: 240
#
# Error reading the file below:
# ../DATA/500ev_EE_ECALDQM_run316766.parquet

# %%
class ParquetDataset(Dataset):
    def __init__(self, file):
        self.parquet = pq.ParquetFile(file)
        self.cols = ['PU', 'lumi', 'EEOccupancyTask_EEOT_digi_occupancy_EE_m.list.item.list.item', 'EEOccupancyTask_EEOT_digi_occupancy_EE_p.list.item.list.item']
    def __getitem__(self, index):
        data = dict([])
        for key in self.cols:
            key = key.split('.')[0]
            try:
                data[key] = np.float64(self.parquet.read_row_groups(index, columns=[key]).to_pydict()[key])
            except:
                data[key] = np.float64(self.parquet.read_row_group(index, columns=[key]).to_pydict()[key])
        return data
    def __len__(self):
        return self.parquet.num_row_groups

# %%
datasetAll = ConcatDataset([ParquetDataset(f) for f in files])

# %%
# GPU
os.environ["CUDA_VISIBLE_DEVICES"] = '1'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Functions: Plot Images, Apply PU Correction, Apply Fake Anomalies, Add Padding around the Images

# %%
# 2D img plot
def plot_2D(img, title = '', doColorbar=True, doLog=False, label='', xlabel='ix', ylabel='iy', vmax=0, doTick=True, doSave=False, figName='plot'):
    fig, ax = plt.subplots()

    cmap = plt.cm.get_cmap('jet')
    cmap.set_bad(color='black')
    cmap.set_under(color='white')
    
    ax.imshow(np.zeros_like(img), origin='lower', cmap=cmap)
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    if doLog:
        im = ax.imshow(img, origin='lower', norm=LogNorm(), cmap=cmap)
        if vmax != 0:
            im = ax.imshow(img, origin='lower', norm=LogNorm(), cmap=cmap, vmax=vmax)
    else:
        im = ax.imshow(img, origin='lower', cmap=cmap)
        if vmax != 0:
            im = ax.imshow(img, origin='lower', cmap=cmap, vmax=vmax)

    if doColorbar:
        ax.figure.colorbar(im, ax=ax, fraction=0.045, pad=0.015, label=label)
        
    off = 0.5
    
    if doTick:
        ax.set_xticks(np.arange(0,22,2)-off)
        ax.set_yticks(np.arange(0,22,2)-off)

        ax.set_xticklabels(np.arange(0,22,2))
        ax.set_yticklabels(np.arange(0,22,2))
    
    # HORIZONTAL DASHES
    for i in np.arange(0, 20, 2):
        x1, x2 = 0, 20
        y1, y2 = i, i
        ax.plot([x1-off, x2-off],[y1-off, y2-off], linewidth=1, linestyle='--', color='black')
    # VERTICAL DASHES
    for i in np.arange(0, 20, 2):
        x1, x2 = i, i
        y1, y2 = 0, 20
        ax.plot([x1-off, x2-off],[y1-off, y2-off], linewidth=1, linestyle='--', color='black')

    
    # labels
    plt.xlabel(xlabel, size=11)
    plt.ylabel(ylabel, size=11)
    plt.title(title, fontsize=13)
    
    if doSave:
        plt.savefig('{}.png'.format(figName))
    
    plt.show()

# %%
# Linear regression on Total Occupancy vs. PU

# Apply PU correction to occupancy maps for all LS
# Then multiply by # of towers (20x20) to make the mean occupancy across the pixels 1.

def applyPUcorr(img, PU, fit):
    scale = fit[0]*PU+fit[1]

    # reshape the `scale` tensor if necessary to perform division with `img` tensor, to match the dimensions
    # -> if the img tensor has the size of e.g. [batch_size, 1, 20, 20] whereas PU has the size [batch_size, 1],
    # -> you need to reshape the PU tensor as [batch_size, 1, 1, 1] by adding the extra 2 dimensions
    # -> but if img and PU tensor have the same shape, you don't add any extra dimensions
    scaleShape = list(scale.shape)
    extraDim = [1]*(len(img.shape)-len(PU.shape)) # additional dimensions
    scaleShape += extraDim
    
    scale = scale.reshape(torch.Size(scaleShape))
    
    corrected = img / scale

    return 20*20*corrected

# %%
def generateFakeAnomCoord(validIndex, nCoord):
    np.random.seed(0)
    fakeIndex = np.random.randint(0, len(validIndex), size=nCoord) # nCoord == batch_size * (# of batches)
    fakeCoord = [validIndex[i] for i in fakeIndex]
    
    return fakeCoord

def applyFakeAnomaly(img, fakeIndex, anomValue=0):
    if len(fakeIndex) == 2:
        nAnomForLS = int(img.shape[0]) - int(torch.count_nonzero(img[range(img.shape[0]), :, fakeIndex[0], fakeIndex[1]]))
        if nAnomForLS != 0:
            print('Already dead '*nAnomForLS)
        
        img[range(img.shape[0]), :, fakeIndex[0], fakeIndex[1]] = anomValue
    # img has the shape of (N of images, N of layers, rows, cols)
    else:
        fakeIndex = torch.tensor(fakeIndex)
        fakeRows = fakeIndex[:,0]  # extract list of rows
        fakeCols = fakeIndex[:,1]  # extract list of cols

        nAnomForLS = int(img.shape[0]) - int(torch.count_nonzero(img[range(img.shape[0]), :, fakeRows, fakeCols]))
        if nAnomForLS != 0:
            print('Already dead '*nAnomForLS)

        img[range(img.shape[0]), :, fakeRows, fakeCols] = anomValue
        
    return img

# %%
def addPadding(img):
    if len(img.shape) == 2:
        pad_top = torch.unsqueeze(img[img.shape[1]-1,:],0)
        img = torch.cat((img, pad_top), 0)
        #plot_2D(img)

        pad_bottom = torch.unsqueeze(img[0,:],0)
        img = torch.cat((pad_bottom, img), 0)
        #plot_2D(img)

        pad_left = torch.unsqueeze(img[:,0], 1)
        img = torch.cat((pad_left, img), 1)
        #plot_2D(img)

        pad_right = torch.unsqueeze(img[:,img.shape[1]-1], 1)
        img = torch.cat((img, pad_right), 1)
        #plot_2D(img.detach().cpu())
        
    elif len(img.shape) == 4:
        pad_top = torch.unsqueeze(img[:,:,img.shape[2]-1,:],2)
        img = torch.cat((img, pad_top), 2)
        #plot_2D(img[10][0].detach().cpu())
        
        pad_bottom = torch.unsqueeze(img[:,:,0,:],2)
        img = torch.cat((pad_bottom, img), 2)
        #plot_2D(img[10][0].detach().cpu())
           
        pad_left = torch.unsqueeze(img[:,:,:,0], 3)
        img = torch.cat((pad_left, img), 3)
        #plot_2D(img[10][0].detach().cpu())
        
        pad_right = torch.unsqueeze(img[:,:,:,img.shape[3]-1], 3)
        img = torch.cat((img, pad_right), 3)
        #plot_2D(img[10][0].detach().cpu())
        
    return img

# %% [markdown]
# ### Import: Average Occupancy Map, Valid Tower List, PU Fit Parameters

# %%
avg_occ_dir = './Avg_Occupancy/'
avg_occupancy = {'p': np.loadtxt('{}avg_occupancy_EEp.csv'.format(avg_occ_dir), delimiter=','), 'm': np.loadtxt('{}avg_occupancy_EEm.csv'.format(avg_occ_dir), delimiter=',')}

# %%
valid_tower_dir = './Valid_Tower_List/'
validIndex = {'p': list(np.loadtxt('{}valid_towers_EEp.csv'.format(valid_tower_dir), delimiter=',').astype(int)), 'm': list(np.loadtxt('{}valid_towers_EEm.csv'.format(valid_tower_dir), delimiter=',').astype(int))}

validIndex['p'] = [ idx.tolist() for idx in validIndex['p']]
validIndex['m'] = [ idx.tolist() for idx in validIndex['m']]

validIndex['p'].remove([7,0])

# %%
PUdir = './PU_Correction/'
fit = {'p': np.loadtxt('{}EEp_PU_Correction_Factor.csv'.format(PUdir), delimiter=','), 'm': np.loadtxt('{}EEm_PU_Correction_Factor.csv'.format(PUdir), delimiter=',')} # fit parameters for EE+(p) and EE-(m)EEp_PU_Correction_Factor.csv', delimiter=','), 'm': np.loadtxt('EEm_PU_Correction_Factor.csv', delimiter=',')} # fit parameters for EE+(p) and EE-(m)

# %% [markdown]
# ### ML: Model Class

# %%
doPadding = True

# %%
class ResBlock(nn.Module):
    '''
    For encoding, define the nominal resnet block
    '''
    def __init__(self, in_channels, out_channels):
        super(ResBlock, self).__init__()
        self.downsample = out_channels//in_channels
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=self.downsample, padding=1)
        self.relu = nn.LeakyReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=self.downsample)

    def forward(self, x):
        residual = x

        out = self.conv1(x)
        out = self.relu(out)
        out = self.conv2(out)

        if self.downsample > 1:
            residual = self.shortcut(x)

        out += residual
        out = self.relu(out)

        return out

class ResBlockTranspose(nn.Module):
    '''
    For decoding, define the transposed resnet block, aka "de-convolution"
    '''
    def __init__(self, in_channels, out_channels, out_shape=None):
        super(ResBlockTranspose, self).__init__()
        self.upsample = in_channels//out_channels  
        self.convT1 = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=3, stride=self.upsample, padding=1)
        #self.convT1 = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=3, stride=self.upsample, padding=0)
        self.relu = nn.LeakyReLU(inplace=True)
        self.convT2 = nn.ConvTranspose2d(out_channels, out_channels, kernel_size=3, padding=1)
        #self.convT2 = nn.ConvTranspose2d(out_channels, out_channels, kernel_size=3, padding=0)

        self.shortcutT = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=1, stride=self.upsample)
        #self.shortcutT = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=1, stride=self.upsample, padding=0)
        self.out_shape = out_shape

    def forward(self, x):
        residual = x
        
        if self.out_shape is None:
            out = self.convT1(x)
        else:
            out = self.convT1(x, output_size=(x.size()[0], x.size()[1], self.out_shape[0], self.out_shape[1]))
        out = self.relu(out)
        out = self.convT2(out)

        if self.upsample > 1:
            if self.out_shape is None:
                residual = self.shortcutT(x)
            else:
                residual = self.shortcutT(x, output_size=(x.size()[0], x.size()[1], self.out_shape[0], self.out_shape[1]))
            
        out += residual
        out = self.relu(out)

        return out

# %%
if doPadding:
    layer0_kernel = 3
    layer2_shape = 10
    final_shape = 22
else:
    layer0_kernel = 5
    layer2_shape = 8
    final_shape = 20

class ResNetAE(nn.Module):
    '''
    Define the full ResNet autoencoder model
    '''
    def __init__(self, in_channels, nblocks, fmaps):
        super(ResNetAE, self).__init__()

        self.fmaps = fmaps
        self.nblocks = nblocks
        self.in_channels = in_channels
        
        # Initialize encoding layers
        self.econv0 = nn.Sequential(nn.Conv2d(in_channels, fmaps[0], kernel_size=layer0_kernel, stride=1, padding=(0,0)), nn.LeakyReLU())
        self.elayer1 = self.block_layers(self.nblocks, [fmaps[0],fmaps[0]], 'enc')
        self.elayer2 = self.block_layers(1, [fmaps[0],fmaps[1]], 'enc')
        self.elayer3 = self.block_layers(self.nblocks, [fmaps[1],fmaps[1]], 'enc')
        
        # Initialize decoding layers
        self.fc = nn.Linear(self.fmaps[1], self.fmaps[1]*int(layer2_shape/2)*int(layer2_shape/2))
        self.dlayer3 = self.block_layers(self.nblocks, [fmaps[1],fmaps[1]], 'dec', out_shape=None)
        self.dlayer2 = self.block_layers(1, [fmaps[1],fmaps[0]], 'dec', out_shape=(layer2_shape, layer2_shape))
        self.dlayer1 = self.block_layers(self.nblocks, [fmaps[0],fmaps[0]], 'dec', out_shape=None)
        self.dconv0 = nn.ConvTranspose2d(fmaps[0], in_channels, kernel_size=layer0_kernel, stride=1, padding=(0,0))
        self.dconv0_relu = nn.LeakyReLU(inplace=True)
        
        self.debug = False
        #self.debug = True

    def block_layers(self, nblocks, fmaps, state, out_shape=None):
        '''
        Convenience function: append several resnet blocks in sequence
        '''
        layers = []
        for _ in range(nblocks):
            if state == 'enc':
                layers.append(ResBlock(fmaps[0], fmaps[1]))
            else:
                layers.append(ResBlockTranspose(fmaps[0], fmaps[1], out_shape)) 
        return nn.Sequential(*layers)

    '''
    For VAE:
    def reparameterize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        # return torch.normal(mu, std)
        esp = torch.randn(*mu.size()).cuda()
        z = mu + std * esp
        return z
    '''

    def forward(self, x):
        
        # Encoding
        if self.debug: print(x.size(), 'input')
        if self.debug: print("Encode")
        x = self.econv0(x)
        if self.debug: print(x.size(), 'econv0')
        x = F.max_pool2d(x, kernel_size=2)
        if self.debug: print(x.size(), 'maxpool')

        x = self.elayer1(x)
        if self.debug: print(x.size(), 'elayer1')
        x = self.elayer2(x)
        if self.debug: print(x.size(), 'elayer2')
        x = self.elayer3(x)
        if self.debug: print(x.size(), 'elayer3')
        
        # Bottleneck comes from GlobalMaxPool
        if self.debug: print("Bottleneck")
        x = F.max_pool2d(x, kernel_size=x.size()[2:])
        if self.debug: print(x.size(), 'GlobalMaxPool')
        x = x.view(x.size()[0], -1)
        if self.debug: print(x.size(), 'flatten')
        
        '''
        For VAE:
        mu, logvar = self.fc_mu(x), self.fc_logvar(x)
        z = self.reparameterize(mu, logvar)
        '''
        
        # Expand bottleneck
        # Dimensions follow encoding steps in reverse, as much as possible
        if self.debug: print("Expand bottleneck")
        x = self.fc(x) # expand
        if self.debug: print(x.size(), 'FC-upsample')
        x = x.view(-1, self.fmaps[1], int(layer2_shape/2), int(layer2_shape/2))
        if self.debug: print(x.size(), 'reshape')
        
        # Decoding
        if self.debug: print("Decode")
        x = self.dlayer3(x)
        if self.debug: print(x.size(), 'dlayer3')
        x = self.dlayer2(x)
        if self.debug: print(x.size(), 'dlayer2')
        x = self.dlayer1(x)
        if self.debug: print(x.size(), 'dlayer1')
        
        x = F.interpolate(x, scale_factor=2)
        if self.debug: print(x.size(), "interp")
        x = self.dconv0(x, output_size=(x.size()[0], self.in_channels, final_shape, final_shape)) 
        if self.debug: print(x.size(), 'dconv0')
        x = self.dconv0_relu(x)
            
        return x
        #return x, mu, logvar

# %% [markdown]
# ### ML Functions: Evalulate during Validation, Calculate FDR

# %%
# Spatial Correction

def do_eval(ae, loader, epoch, doPadding=False, isDead=False, isHot=False, fakeIndices=[], avg_occ=[]):
    loss_ = []

    # Average Occupancy Map for Spatial Correction
    avg_occ = torch.tensor(avg_occ).to(device)
    avg_occ[avg_occ==0] = 1
    
    if doPadding:
        avg_occ = addPadding(avg_occ)
    
    for i, data in enumerate(loader):
        X, PU = data['EEOccupancyTask_EEOT_digi_occupancy_EE_{}'.format(EE)].to(device), data['PU'].to(device)
        
        # PU Correction
        X = applyPUcorr(X, PU, fit[EE]).float()
        
        # Fake anomaly value
        if isDead or isHot:
            if isDead:
                anomValue = 0
            elif isHot:
                f = 0.2

                hotValue = torch.tensor([25*500*f]*batch_size).to(device)
                hotValue = torch.unsqueeze(hotValue, 1)

                hotValue = applyPUcorr(hotValue, PU, fit[EE]).float()

                hotValue[hotValue > 8.] = 8. # upperbound cutoff

                anomValue = hotValue
                
            fakeIndex = fakeIndices[i*batch_size:(i+1)*batch_size]
        
            # Apply Fake Anomaly
            X = applyFakeAnomaly(X, fakeIndex, anomValue)
        
        # Padding
        if doPadding:
            X = addPadding(X)
        
        # Feed to AE
        Xreco = ae(X)
        
        # Calculate loss: Spatial Correction
        losses = F.mse_loss(Xreco.float()/avg_occ.float(), X.float()/avg_occ.float(), reduction='none')
        
        # Process loss maps into good and anom losses
        
        # Padding
        if doPadding:
            losses = losses[:,:,1:21,1:21]

        # Get losses of anomalous for anomaly validation and of good towers for good validation
            if isDead or isHot:
                fakeIndex = torch.tensor(fakeIndex)
                fakeRows = fakeIndex[:,0]  # extract list of rows
                fakeCols = fakeIndex[:,1]  # extract list of cols
                anom_losses = losses[range(losses.shape[0]), :, fakeRows, fakeCols]

                loss_.append(anom_losses.tolist())

            else:
                validTowers = torch.tensor(validIndex[EE])
                good_losses = losses[:, :, validTowers[:,0], validTowers[:,1]]
                
                loss_.append(good_losses.tolist())

        # For best epoch: get anomaly losses to make average loss map for anomaly scenario
        if epoch == 32:
            if isDead:
                dead_index = anom_losses.nonzero()[:,0]

                for index in dead_index:
                    dead_loss_epoch50['index'].append(fakeIndex[index].detach().cpu().numpy())
                    dead_loss_epoch50['loss'].append(anom_losses[index].detach().cpu().numpy())
                    
                dead_low_loss = anom_losses < 0.4
                if len(dead_low_loss.nonzero()) > 0:
                    dead_low_index = dead_low_loss.nonzero()[:,0]

                    for index in dead_low_index:
                        low_dead_loss_index['index'].append(fakeIndex[index])
                        low_dead_loss_index['loss'].append(anom_losses[index].detach().cpu().numpy())
                    
            elif isHot:
                hot_index = anom_losses.nonzero()[:,0]

                for index in hot_index:
                    hot_loss_epoch50['index'].append(fakeIndex[index].detach().cpu().numpy())
                    hot_loss_epoch50['loss'].append(anom_losses[index].detach().cpu().numpy())
                    
                hot_low_loss = anom_losses < 1.
                if len(hot_low_loss.nonzero()) > 0:
                    hot_low_index = hot_low_loss.nonzero()[:,0]

                    for index in hot_low_index:
                        low_hot_loss_index['index'].append(fakeIndex[index])
                        low_hot_loss_index['loss'].append(anom_losses[index].detach().cpu().numpy())
                
    # Append losses to list
    if isDead:
        loss_ = np.concatenate(loss_)
        val_dead_loss.append(loss_)
        print('\nEpoch {} > Dead Val loss: {:.4f}'.format(epoch, loss_.mean()))
    elif isHot:
        loss_ = np.concatenate(loss_)
        val_hot_loss.append(loss_)
        print('\nEpoch {} > Hot (f={}) Val loss: {:.4f}'.format(epoch, f, loss_.mean()))
    else:
        loss_ = np.concatenate(loss_)
        val_good_loss.append(loss_)
        print('\nEpoch {} > Good Val loss: {:.4f}'.format(epoch, loss_.mean()))
    
    return loss_

# %%
def get_roc(loss_maps, loss_map_anoms):
    anom_map=loss_map_anoms
    norm_map=loss_maps
   
    anom_thres=np.percentile(anom_map,1)
    
    print('Anomaly threshold = %.4f'%(anom_thres))
    
    FP = len(norm_map[norm_map > anom_thres])
    TP = len(anom_map[anom_map > anom_thres])
    
    FN = len(anom_map[anom_map < anom_thres])
    TN = len(norm_map[norm_map < anom_thres])
    
    FNR = FN/(FN+TP)
    FPR = FP/(FP+TN)
    
    TPR = TP/(TP+FN)
    TNR = TN/(TN+FP)
    
    FDR = FP/(FP+TP)
    
    #print('TPR = {:.4f}'.format(TPR))
    
    print('FDR = {:.4f}'.format(FDR))
    
    return FDR, anom_thres

# %% [markdown]
# ### Validation (Spatial Correction): EE+

# %%
# Split into training and validation set
n_train = int(0.7*len(datasetAll))
n_val = len(datasetAll) - n_train

idxs = np.random.permutation(len(datasetAll))
idxs_train, idxs_val = idxs[:n_train], idxs[-n_val:]

batch_size = 32
val_sampler = sampler.SequentialSampler(idxs_val)
val_loader = DataLoader(dataset=datasetAll, batch_size=batch_size, num_workers=10, sampler=val_sampler, pin_memory=True, drop_last=True)

# %%
EE = 'p'
modelDir = './MODELS/EE{}/'.format(EE)

epochs = 50 # Total number of epochs trained

# %%
fakeIndices = generateFakeAnomCoord(validIndex[EE], nCoord = batch_size*len(val_loader))

# %%
val_good_loss, val_dead_loss, val_hot_loss = [], [], []

dead_loss_epoch50 = {'index': [], 'loss': []}
hot_loss_epoch50 = {'index': [], 'loss': []}

low_dead_loss_index = {'index': [], 'loss': []}
low_hot_loss_index = {'index': [], 'loss': []}

FDRs = {'dead': [], 'hot': []}
all_anom_thres = {'dead': [], 'hot': []}

for e in range(epochs):
    epoch = e+1

    # Run Validation
    model = torch.load('{}ae_epoch{}.pth'.format(modelDir, epoch))
    model.eval()
    print("\n>> Validation (Spatial Correction): Good samples <<<<<<<<")
    good_losses = do_eval(model, val_loader, epoch, doPadding=doPadding, isDead=False, isHot=False, avg_occ=avg_occupancy[EE])

    # Calculate FDR for Dead tower 
    print("\n>> Validation (Spatial Correction): Dead Tower samples <<<<<<<<")
    dead_losses = do_eval(model, val_loader, epoch, doPadding=doPadding, isDead=True, isHot=False, fakeIndices=fakeIndices, avg_occ=avg_occupancy[EE])

    FDR, anom_thres = get_roc(good_losses, dead_losses)
    FDRs['dead'].append(FDR)
    all_anom_thres['dead'].append(anom_thres)

    # Calculate FDR for Hot tower 
    print("\n>> Validation (Spatial Correction): Hot Tower samples <<<<<<<<")
    hot_losses = do_eval(model, val_loader, epoch, doPadding=doPadding, isDead=False, isHot=True, fakeIndices=fakeIndices, avg_occ=avg_occupancy[EE])

    FDR, anom_thres = get_roc(good_losses, hot_losses)
    FDRs['hot'].append(FDR)
    all_anom_thres['hot'].append(anom_thres)

    #print('\nFDR')
    #print(FDRs)
    #print('\nAnomaly Threshold')
    #print(all_anom_thres)
# Out:
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 1 > Good Val loss: 0.0215
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 1 > Dead Val loss: 0.9416
# Anomaly threshold = 0.4596
# FDR = 0.1727
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 1 > Hot (f=0.2) Val loss: 36.9801
# Anomaly threshold = 1.8152
# FDR = 0.0012
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 2 > Good Val loss: 0.0199
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 2 > Dead Val loss: 0.9028
# Anomaly threshold = 0.4262
# FDR = 0.1713
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 2 > Hot (f=0.2) Val loss: 37.2780
# Anomaly threshold = 1.7991
# FDR = 0.0015
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 3 > Good Val loss: 0.0196
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 3 > Dead Val loss: 0.9020
# Anomaly threshold = 0.4314
# FDR = 0.1617
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 3 > Hot (f=0.2) Val loss: 37.3414
# Anomaly threshold = 1.7422
# FDR = 0.0012
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 4 > Good Val loss: 0.0193
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 4 > Dead Val loss: 0.9162
# Anomaly threshold = 0.4307
# FDR = 0.1446
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 4 > Hot (f=0.2) Val loss: 37.0019
# Anomaly threshold = 1.6564
# FDR = 0.0012
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 5 > Good Val loss: 0.0188
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 5 > Dead Val loss: 0.8880
# Anomaly threshold = 0.4286
# FDR = 0.1405
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 5 > Hot (f=0.2) Val loss: 37.1213
# Anomaly threshold = 1.6860
# FDR = 0.0008
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 6 > Good Val loss: 0.0188
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 6 > Dead Val loss: 0.8966
# Anomaly threshold = 0.4296
# FDR = 0.1344
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 6 > Hot (f=0.2) Val loss: 36.7549
# Anomaly threshold = 1.6315
# FDR = 0.0010
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 7 > Good Val loss: 0.0189
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 7 > Dead Val loss: 0.8524
# Anomaly threshold = 0.4075
# FDR = 0.1591
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 7 > Hot (f=0.2) Val loss: 36.8973
# Anomaly threshold = 1.6759
# FDR = 0.0010
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 8 > Good Val loss: 0.0187
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 8 > Dead Val loss: 0.8549
# Anomaly threshold = 0.4087
# FDR = 0.1534
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 8 > Hot (f=0.2) Val loss: 36.7170
# Anomaly threshold = 1.6075
# FDR = 0.0010
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 9 > Good Val loss: 0.0187
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 9 > Dead Val loss: 0.8786
# Anomaly threshold = 0.4286
# FDR = 0.1346
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 9 > Hot (f=0.2) Val loss: 36.8605
# Anomaly threshold = 1.5764
# FDR = 0.0018
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 10 > Good Val loss: 0.0189
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 10 > Dead Val loss: 0.8982
# Anomaly threshold = 0.4340
# FDR = 0.1274
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 10 > Hot (f=0.2) Val loss: 36.7554
# Anomaly threshold = 1.5664
# FDR = 0.0017
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 11 > Good Val loss: 0.0186
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 11 > Dead Val loss: 0.8633
# Anomaly threshold = 0.4081
# FDR = 0.1410
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 11 > Hot (f=0.2) Val loss: 36.7850
# Anomaly threshold = 1.6019
# FDR = 0.0010
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 12 > Good Val loss: 0.0185
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 12 > Dead Val loss: 0.8739
# Anomaly threshold = 0.4111
# FDR = 0.1355
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 12 > Hot (f=0.2) Val loss: 36.5019
# Anomaly threshold = 1.6238
# FDR = 0.0008
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 13 > Good Val loss: 0.0183
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 13 > Dead Val loss: 0.8612
# Anomaly threshold = 0.4079
# FDR = 0.1350
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 13 > Hot (f=0.2) Val loss: 36.5949
# Anomaly threshold = 1.5202
# FDR = 0.0016
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 14 > Good Val loss: 0.0187
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 14 > Dead Val loss: 0.8597
# Anomaly threshold = 0.3887
# FDR = 0.1626
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 14 > Hot (f=0.2) Val loss: 36.3327
# Anomaly threshold = 1.5486
# FDR = 0.0015
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 15 > Good Val loss: 0.0184
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 15 > Dead Val loss: 0.8660
# Anomaly threshold = 0.4019
# FDR = 0.1415
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 15 > Hot (f=0.2) Val loss: 36.3154
# Anomaly threshold = 1.5359
# FDR = 0.0011
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 16 > Good Val loss: 0.0182
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 16 > Dead Val loss: 0.8631
# Anomaly threshold = 0.3985
# FDR = 0.1393
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 16 > Hot (f=0.2) Val loss: 35.9110
# Anomaly threshold = 1.4550
# FDR = 0.0016
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 17 > Good Val loss: 0.0185
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 17 > Dead Val loss: 0.8429
# Anomaly threshold = 0.3922
# FDR = 0.1561
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 17 > Hot (f=0.2) Val loss: 36.2556
# Anomaly threshold = 1.5825
# FDR = 0.0012
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 18 > Good Val loss: 0.0184
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 18 > Dead Val loss: 0.8679
# Anomaly threshold = 0.4160
# FDR = 0.1340
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 18 > Hot (f=0.2) Val loss: 35.6227
# Anomaly threshold = 1.5135
# FDR = 0.0013
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 19 > Good Val loss: 0.0182
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 19 > Dead Val loss: 0.8643
# Anomaly threshold = 0.3954
# FDR = 0.1432
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 19 > Hot (f=0.2) Val loss: 35.5507
# Anomaly threshold = 1.5126
# FDR = 0.0013
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 20 > Good Val loss: 0.0184
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 20 > Dead Val loss: 0.8780
# Anomaly threshold = 0.4067
# FDR = 0.1323
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 20 > Hot (f=0.2) Val loss: 35.3008
# Anomaly threshold = 1.4624
# FDR = 0.0017
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 21 > Good Val loss: 0.0184
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 21 > Dead Val loss: 0.8726
# Anomaly threshold = 0.4021
# FDR = 0.1398
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 21 > Hot (f=0.2) Val loss: 35.4222
# Anomaly threshold = 1.4532
# FDR = 0.0019
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 22 > Good Val loss: 0.0183
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 22 > Dead Val loss: 0.8514
# Anomaly threshold = 0.3832
# FDR = 0.1583
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 22 > Hot (f=0.2) Val loss: 35.6781
# Anomaly threshold = 1.5551
# FDR = 0.0011
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 23 > Good Val loss: 0.0183
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 23 > Dead Val loss: 0.8444
# Anomaly threshold = 0.3828
# FDR = 0.1548
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 23 > Hot (f=0.2) Val loss: 36.0098
# Anomaly threshold = 1.5029
# FDR = 0.0012
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 24 > Good Val loss: 0.0187
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 24 > Dead Val loss: 0.8915
# Anomaly threshold = 0.4143
# FDR = 0.1312
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 24 > Hot (f=0.2) Val loss: 34.9604
# Anomaly threshold = 1.3907
# FDR = 0.0018
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 25 > Good Val loss: 0.0181
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 25 > Dead Val loss: 0.8518
# Anomaly threshold = 0.3743
# FDR = 0.1616
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 25 > Hot (f=0.2) Val loss: 35.5449
# Anomaly threshold = 1.4430
# FDR = 0.0014
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 26 > Good Val loss: 0.0186
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 26 > Dead Val loss: 0.8717
# Anomaly threshold = 0.4087
# FDR = 0.1452
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 26 > Hot (f=0.2) Val loss: 35.2501
# Anomaly threshold = 1.3712
# FDR = 0.0025
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 27 > Good Val loss: 0.0184
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 27 > Dead Val loss: 0.8633
# Anomaly threshold = 0.3850
# FDR = 0.1548
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 27 > Hot (f=0.2) Val loss: 35.7315
# Anomaly threshold = 1.4341
# FDR = 0.0025
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 28 > Good Val loss: 0.0182
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 28 > Dead Val loss: 0.8789
# Anomaly threshold = 0.4159
# FDR = 0.1260
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 28 > Hot (f=0.2) Val loss: 35.2818
# Anomaly threshold = 1.4938
# FDR = 0.0018
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 29 > Good Val loss: 0.0186
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 29 > Dead Val loss: 0.8355
# Anomaly threshold = 0.4044
# FDR = 0.1458
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 29 > Hot (f=0.2) Val loss: 36.2853
# Anomaly threshold = 1.5421
# FDR = 0.0011
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 30 > Good Val loss: 0.0181
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 30 > Dead Val loss: 0.8760
# Anomaly threshold = 0.4122
# FDR = 0.1255
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 30 > Hot (f=0.2) Val loss: 35.4360
# Anomaly threshold = 1.4393
# FDR = 0.0022
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 31 > Good Val loss: 0.0183
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 31 > Dead Val loss: 0.8680
# Anomaly threshold = 0.4072
# FDR = 0.1368
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 31 > Hot (f=0.2) Val loss: 35.8119
# Anomaly threshold = 1.5345
# FDR = 0.0011
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 32 > Good Val loss: 0.0181
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 32 > Dead Val loss: 0.8725
# Anomaly threshold = 0.4170
# FDR = 0.1230
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 32 > Hot (f=0.2) Val loss: 35.5415
# Anomaly threshold = 1.5144
# FDR = 0.0013
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 33 > Good Val loss: 0.0184
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 33 > Dead Val loss: 0.8311
# Anomaly threshold = 0.3664
# FDR = 0.1714
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 33 > Hot (f=0.2) Val loss: 36.0902
# Anomaly threshold = 1.5519
# FDR = 0.0011
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 34 > Good Val loss: 0.0185
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 34 > Dead Val loss: 0.8891
# Anomaly threshold = 0.4113
# FDR = 0.1332
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 34 > Hot (f=0.2) Val loss: 36.4919
# Anomaly threshold = 1.6044
# FDR = 0.0010
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 35 > Good Val loss: 0.0184
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 35 > Dead Val loss: 0.8682
# Anomaly threshold = 0.3769
# FDR = 0.1576
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 35 > Hot (f=0.2) Val loss: 35.8751
# Anomaly threshold = 1.4398
# FDR = 0.0015
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 36 > Good Val loss: 0.0184
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 36 > Dead Val loss: 0.8519
# Anomaly threshold = 0.3676
# FDR = 0.1731
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 36 > Hot (f=0.2) Val loss: 36.0672
# Anomaly threshold = 1.4783
# FDR = 0.0015
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 37 > Good Val loss: 0.0183
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 37 > Dead Val loss: 0.8603
# Anomaly threshold = 0.3824
# FDR = 0.1515
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 37 > Hot (f=0.2) Val loss: 36.2060
# Anomaly threshold = 1.5570
# FDR = 0.0012
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 38 > Good Val loss: 0.0187
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 38 > Dead Val loss: 0.8942
# Anomaly threshold = 0.3878
# FDR = 0.1490
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 38 > Hot (f=0.2) Val loss: 35.3088
# Anomaly threshold = 1.5072
# FDR = 0.0016
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 39 > Good Val loss: 0.0181
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 39 > Dead Val loss: 0.8759
# Anomaly threshold = 0.3967
# FDR = 0.1396
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 39 > Hot (f=0.2) Val loss: 35.4360
# Anomaly threshold = 1.5007
# FDR = 0.0016
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 40 > Good Val loss: 0.0180
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 40 > Dead Val loss: 0.8620
# Anomaly threshold = 0.3702
# FDR = 0.1601
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 40 > Hot (f=0.2) Val loss: 35.4882
# Anomaly threshold = 1.5001
# FDR = 0.0015
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 41 > Good Val loss: 0.0182
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 41 > Dead Val loss: 0.8461
# Anomaly threshold = 0.3777
# FDR = 0.1656
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 41 > Hot (f=0.2) Val loss: 35.7334
# Anomaly threshold = 1.5334
# FDR = 0.0016
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 42 > Good Val loss: 0.0180
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 42 > Dead Val loss: 0.8497
# Anomaly threshold = 0.3818
# FDR = 0.1525
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 42 > Hot (f=0.2) Val loss: 35.2863
# Anomaly threshold = 1.5870
# FDR = 0.0010
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 43 > Good Val loss: 0.0182
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 43 > Dead Val loss: 0.8630
# Anomaly threshold = 0.3863
# FDR = 0.1450
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 43 > Hot (f=0.2) Val loss: 35.3458
# Anomaly threshold = 1.5286
# FDR = 0.0013
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 44 > Good Val loss: 0.0181
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 44 > Dead Val loss: 0.8821
# Anomaly threshold = 0.3880
# FDR = 0.1391
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 44 > Hot (f=0.2) Val loss: 34.6114
# Anomaly threshold = 1.4716
# FDR = 0.0017
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 45 > Good Val loss: 0.0179
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 45 > Dead Val loss: 0.8629
# Anomaly threshold = 0.3938
# FDR = 0.1395
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 45 > Hot (f=0.2) Val loss: 35.5239
# Anomaly threshold = 1.4968
# FDR = 0.0013
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 46 > Good Val loss: 0.0182
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 46 > Dead Val loss: 0.8501
# Anomaly threshold = 0.3621
# FDR = 0.1747
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 46 > Hot (f=0.2) Val loss: 35.6585
# Anomaly threshold = 1.6243
# FDR = 0.0009
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 47 > Good Val loss: 0.0180
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 47 > Dead Val loss: 0.8730
# Anomaly threshold = 0.3897
# FDR = 0.1410
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 47 > Hot (f=0.2) Val loss: 35.5717
# Anomaly threshold = 1.4305
# FDR = 0.0022
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 48 > Good Val loss: 0.0183
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 48 > Dead Val loss: 0.8577
# Anomaly threshold = 0.3734
# FDR = 0.1610
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 48 > Hot (f=0.2) Val loss: 35.7816
# Anomaly threshold = 1.5436
# FDR = 0.0013
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 49 > Good Val loss: 0.0183
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 49 > Dead Val loss: 0.8509
# Anomaly threshold = 0.3642
# FDR = 0.1755
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 49 > Hot (f=0.2) Val loss: 35.5549
# Anomaly threshold = 1.4981
# FDR = 0.0012
#
# >> Validation (Spatial Correction): Good samples <<<<<<<<
#
# Epoch 50 > Good Val loss: 0.0179
#
# >> Validation (Spatial Correction): Dead Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 50 > Dead Val loss: 0.8631
# Anomaly threshold = 0.3782
# FDR = 0.1487
#
# >> Validation (Spatial Correction): Hot Tower samples <<<<<<<<
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
# Already dead
#
# Epoch 50 > Hot (f=0.2) Val loss: 35.9046
# Anomaly threshold = 1.4728
# FDR = 0.0015

# %%
dead_loss_avg = np.array([[0.]*20]*20)

for i, index in enumerate(dead_loss_epoch50['index']):
    index = index.tolist()
    dead_loss_avg[index[0]][index[1]] += dead_loss_epoch50['loss'][i]

dead_loss_avg /= np.sum(dead_loss_avg)

plot_2D(dead_loss_avg, label='A.U', vmax=0.015)

# %%
hot_loss_avg = np.array([[0.]*20]*20)

for i, index in enumerate(hot_loss_epoch50['index']):
    index = index.tolist()
    hot_loss_avg[index[0]][index[1]] += hot_loss_epoch50['loss'][i]

hot_loss_avg /= np.sum(hot_loss_avg)

plot_2D(hot_loss_avg, label='A.U', doLog=True)

# %% [markdown]
# ### Find Best Epoch based on FDR, Plot Loss Histogram with Anomaly Threshold

# %%
# FDR vs epoch (Dead Tower)
plt.plot(range(1, epochs+1), FDRs['dead'], label='Dead tower')
plt.xlabel('epoch')
plt.ylabel('FDR')
plt.legend()
plt.title('FDR vs epoch (Dead Tower)')

plt.savefig('{}/FDR_vs_Epoch_DeadTower_EE{}.png'.format(figOutDir, EE))

plt.show()

# %%
# Find the lowest FDR from all epochs
best_epoch_idx = {'dead': 0, 'hot': 0}
best_FDR = {'dead': 0, 'hot': 0}
thres = {'dead': 0, 'hot': 0}

best_epoch_idx['dead'] = FDRs['dead'].index(min(FDRs['dead']))
best_FDR['dead'] = FDRs['dead'][best_epoch_idx['dead']]
thres['dead'] = all_anom_thres['dead'][best_epoch_idx['dead']]

print('Dead Tower')
print('Best FDR of {:.4f} at epoch {}'.format(best_FDR['dead'], best_epoch_idx['dead']+1))
print('Corresponding Anomaly Threshold = {:.4f}'.format(thres['dead']))
# Out:
# Dead Tower
# Best FDR of 0.1230 at epoch 32
# Corresponding Anomaly Threshold = 0.4170

# %%
# Histogram of dead tower losses for its best FDR epoch
bins = np.logspace(-1.5, 1.5, int((1.5+1.5)*20))

plt.hist(np.clip(np.array(val_good_loss[best_epoch_idx['dead']]).ravel(), bins[0], bins[-1]), bins=bins, histtype='step',range=(0, 1e3), label='Good Tower Loss')
plt.hist(np.clip(np.array(val_dead_loss[best_epoch_idx['dead']]).ravel(), bins[0], bins[-1]), bins=bins, histtype='step',range=(0, 1e3), label='Dead Tower Loss')

plt.vlines(x=all_anom_thres['dead'][best_epoch_idx['dead']], ymin=0, ymax=1e8, color='red', label='Dead Tower Anomaly Threshold')

plt.legend()

plt.xlabel('Loss')
plt.ylabel('Number of Towers / bin')
plt.yscale('log')
plt.xscale('log')

plt.title('Dead Tower Validation Loss Histogram')
#plt.title('Dead Tower Validation Loss Histogram (at epoch {} with best FDR of {:.2f})'.format(best_epoch_idx['dead']+1, best_FDR['dead']))

plt.savefig('{}/DeadTower_Loss_EE{}_SpatialCorrection.png'.format(figOutDir, EE))

plt.show()

# %%
# FDR vs epoch (Hot Tower)
plt.plot(range(1, epochs+1), FDRs['hot'], label='Hot tower')
plt.xlabel('epoch')
plt.ylabel('FDR')
plt.legend()
plt.title('FDR vs epoch (Hot Tower)')

plt.savefig('{}/FDR_vs_Epoch_HotTower_EE{}.png'.format(figOutDir, EE))

plt.show()

# %%
# Find the lowest FDR from all epochs
best_epoch_idx['hot'] = FDRs['hot'].index(min(FDRs['hot']))
best_FDR['hot'] = FDRs['hot'][best_epoch_idx['hot']]
thres['hot'] = all_anom_thres['hot'][best_epoch_idx['hot']]

print('Hot Tower')
print('Best FDR of {:.4f} at epoch {}'.format(best_FDR['hot'], best_epoch_idx['hot']+1))
print('Corresponding Anomaly Threshold = {:.4f}'.format(thres['hot']))
# Out:
# Hot Tower
# Best FDR of 0.0008 at epoch 5
# Corresponding Anomaly Threshold = 1.6860

# %%
# Histogram of hot tower losses for its best FDR epoch
bins = np.logspace(-1.5, 1.5, int((1.5+1.5)*20))

plt.hist(np.clip(np.array(val_good_loss[best_epoch_idx['hot']]).ravel(), bins[0], bins[-1]), bins=bins, histtype='step',range=(0, 1e3), label='Good Tower Loss')
plt.hist(np.clip(np.array(val_hot_loss[best_epoch_idx['hot']]).ravel(), bins[0], bins[-1]), bins=bins, histtype='step',range=(0, 1e3), label='Hot Tower Loss')

plt.vlines(x=all_anom_thres['hot'][best_epoch_idx['hot']], ymin=0, ymax=1e8, color='red', label='Hot Tower Anomaly Threshold')

plt.legend()

plt.xlabel('Loss')
plt.ylabel('Number of Towers / bin')
plt.yscale('log')
plt.xscale('log')

plt.title('Hot Tower Validation Loss Histogram')
#plt.title('Hot Tower Validation Loss Histogram (at epoch {} with best FDR of {:.2f})'.format(best_epoch_idx['hot']+1, best_FDR['hot']))

plt.savefig('{}/HotTower_Loss_EE{}_SpatialCorrection.png'.format(figOutDir, EE))

plt.show()

# %% [markdown]
# Hot tower FDR gets worse with spatial correction. That's because avg loss of hot tower case has the opposite gradient of average occupancy map. That is, the hot tower average loss is parallel to the "reverse" average occupancy map below.

# %%
plot_2D(-1*avg_occupancy[EE]+np.max(avg_occupancy[EE]))

# %% [markdown]
# However, this is mitigated with time correction.
